# %%
# Import 需要的套件
import os
import numpy as np
import pandas as pd

# 設定 data_path
dir_data = './data/'

# %%
f_app_train = os.path.join(dir_data, 'application_train.csv')
app_train = pd.read_csv(f_app_train)
type(app_train)
# Out:
# pandas.core.frame.DataFrame

# %%
app_train['SK_ID_CURR']
# Out:
# 0         100002
# 1         100003
# 2         100004
# 3         100006
# 4         100007
# 5         100008
# 6         100009
# 7         100010
# 8         100011
# 9         100012
# 10        100014
# 11        100015
# 12        100016
# 13        100017
# 14        100018
# 15        100019
# 16        100020
# 17        100021
# 18        100022
# 19        100023
# 20        100024
# 21        100025
# 22        100026
# 23        100027
# 24        100029
# 25        100030
# 26        100031
# 27        100032
# 28        100033
# 29        100034
#            ...
# 307481    456225
# 307482    456226
# 307483    456227
# 307484    456228
# 307485    456229
# 307486    456230
# 307487    456231
# 307488    456232
# 307489    456233
# 307490    456234
# 307491    456235
# 307492    456236
# 307493    456237
# 307494    456238
# 307495    456239
# 307496    456240
# 307497    456241
# 307498    456242
# 307499    456243
# 307500    456244
# 307501    456245
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
app_train.describe()
# Out:
#           SK_ID_CURR         TARGET   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  307511.000000  307511.000000  307511.000000      3.075110e+05
# mean   278180.518577       0.080729       0.417052      1.687979e+05
# std    102790.175348       0.272419       0.722121      2.371231e+05
# min    100002.000000       0.000000       0.000000      2.565000e+04
# 25%    189145.500000       0.000000       0.000000      1.125000e+05
# 50%    278202.000000       0.000000       0.000000      1.471500e+05
# 75%    367142.500000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  3.075110e+05  307499.000000     3.072330e+05
# mean   5.990260e+05   27108.573909     5.383962e+05
# std    4.024908e+05   14493.737315     3.694465e+05
# min    4.500000e+04    1615.500000     4.050000e+04
# 25%    2.700000e+05   16524.000000     2.385000e+05
# ...

# %%
column_info = pd.DataFrame({'colanme':app_train.columns,'object':app_train.dtypes})
column_info.reset_index(drop=True, inplace=True)
column_info.tail()
# Out:
#                         colanme   object
# 117   AMT_REQ_CREDIT_BUREAU_DAY  float64
# 118  AMT_REQ_CREDIT_BUREAU_WEEK  float64
# 119   AMT_REQ_CREDIT_BUREAU_MON  float64
# 120   AMT_REQ_CREDIT_BUREAU_QRT  float64
# 121  AMT_REQ_CREDIT_BUREAU_YEAR  float64

# %%
column_name = 'SK_ID_CURR'
column = app_train[column_name]
print('{}: mean={}, max={}, std={}'.format(column_name, column.mean(), column.max(), column.std()))
# Out:
# SK_ID_CURR: mean=278180.51857657125, max=456255, std=102790.17534842459

# %%
column
new_column = column.dropna()

# %%
plt.xlabel(column_name)
plt.ylabel('Probability')
plt.title('Histogram:{}'.format(column_name))
plt.hist(new_column, 40,  density=True, alpha=0.5)
# plt.show()
# Out:
# (array([2.79101059e-06, 2.78005686e-06, 2.81401342e-06, 2.82314153e-06,
#         2.83482551e-06, 2.79977357e-06, 2.80598069e-06, 2.78407322e-06,
#         2.80232944e-06, 2.80780631e-06, 2.79137571e-06, 2.77129387e-06,
#         2.81036218e-06, 2.82496715e-06, 2.82241128e-06, 2.81109243e-06,
#         2.78918497e-06, 2.81255292e-06, 2.81218780e-06, 2.82752302e-06,
#         2.79210596e-06, 2.81656929e-06, 2.81985541e-06, 2.78955009e-06,
#         2.77640561e-06, 2.82314153e-06, 2.81876004e-06, 2.82788815e-06,
#         2.83811163e-06, 2.80744118e-06, 2.81729954e-06, 2.87425894e-06,
#         2.82314153e-06, 2.77531024e-06, 2.70009462e-06, 2.80269457e-06,
#         2.87462407e-06, 2.77604049e-06, 2.80561556e-06, 2.80488531e-06]),
#  array([100002.   , 108908.325, 117814.65 , 126720.975, 135627.3  ,
#         144533.625, 153439.95 , 162346.275, 171252.6  , 180158.925,
#         189065.25 , 197971.575, 206877.9  , 215784.225, 224690.55 ,
# ...
